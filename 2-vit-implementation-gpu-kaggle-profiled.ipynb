# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import random
import timeit
from tqdm import tqdm  #Progress bar

import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms
from torch.profiler import profile, record_function, ProfilerActivity #For Profiling



RANDOM_SEED = 42
BATCH_SIZE = 512
EPOCHS =  70   #40


LEARNING_RATE = 1e-4 #We use small steps
NUM_CLASSES = 10 #using MNIST data
PATCH_SIZE = 4
IMG_SIZE = 28
IN_CHANNELS = 1
NUM_HEADS = 8
DROPOUT = 0.001       #using 0.1 makes the result worse
HIDDEN_DIM = 768 #the hidden dimension of the MLP head
ADAM_WEIGHT_DECAY = 0
ADAM_BETAS = (0.9, 0.999)
ACTIVATION = 'relu'  #try 'gelu'
NUM_ENCODERS = 4
EMBED_DIM = (PATCH_SIZE ** 2) * IN_CHANNELS #16
NUM_PATCHES = (IMG_SIZE // PATCH_SIZE) ** 2 #49

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
torch.cuda.manual_seed(RANDOM_SEED)
torch.cuda.manual_seed_all(RANDOM_SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False


#Now we define our device
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)



class PatchEmbedding(nn.Module):
    def __init__(self, embed_dim, patch_size, num_patches, dropout, in_channels):
        super().__init__()
        self.patcher = nn.Sequential(
            nn.Conv2d(
                in_channels=in_channels,
                out_channels = embed_dim,
                kernel_size=patch_size,
                stride=patch_size

            ),
            nn.Flatten(2)
        )

        self.cls_token = nn.Parameter(torch.randn(size=(1, in_channels, embed_dim)), requires_grad=True)

        #Position Embeddings
        self.position_embeddings = nn.Parameter(torch.randn(size=(1, num_patches*1, embed_dim)), requires_grad=True)
        self.dropout = nn.Dropout(p=dropout)


    def forward(self, x):
        cls_token = self.cls_token.expand(x.shape[0], -1, -1) #'-1' here means this is protected dimension. We won't change it

        x = self.patcher(x).permute(0, 2, 1)
        x = torch.cat([cls_token, x], dim=1)
        #x = self.position_embeddings + x
        x = self.dropout(x) #we apply dropout
        return x

model = PatchEmbedding(EMBED_DIM, PATCH_SIZE, NUM_PATCHES, DROPOUT, IN_CHANNELS).to(device)
x = torch.randn(512, 1, 28, 28).to(device)
print(model(x).shape)



#Profiler Block
with profile(activities=[
        ProfilerActivity.CPU, ProfilerActivity.CUDA], profile_memory=True, record_shapes=True) as prof:
    with record_function("model_inference"):
        model(x)




#Define the Vision Transformer Class
class ViT(nn.Module):
    def __init__(self, num_patches, img_size, num_classes, patch_size, embed_dim, num_encoders, num_heads, hidden_dim, dropout, activation, in_channels):
        super().__init__()
        self.embeddings_block = PatchEmbedding(embed_dim, patch_size, num_patches, dropout, in_channels)

        encoder_layer = nn.TransformerEncoderLayer(d_model=embed_dim, nhead=num_heads, dropout=dropout, activation=activation, batch_first=True, norm_first=True)
        self.encoder_blocks = nn.TransformerEncoder(encoder_layer, num_layers=num_encoders)

        self.mlp_head = nn.Sequential(
            nn.LayerNorm(normalized_shape=embed_dim),
            nn.Linear(in_features=embed_dim, out_features=num_classes)
        )


    def forward(self, x):
        x = self.embeddings_block(x)
        x = self.encoder_blocks(x)
        x = self.mlp_head(x[:, 0, :])
        return x

model = ViT(NUM_PATCHES, IMG_SIZE, NUM_CLASSES, PATCH_SIZE, EMBED_DIM, NUM_ENCODERS, NUM_HEADS, HIDDEN_DIM, DROPOUT, ACTIVATION, IN_CHANNELS).to(device)
x = torch.randn(512, 1, 28, 28).to(device)#This line prevents issues when running on GPU
print(model(x).shape)


#pwd #prints current working directory before training begins


train_df = pd.read_csv("/kaggle/input/digit-recognizer/train.csv")
test_df = pd.read_csv("/kaggle/input/digit-recognizer/test.csv")
#submission_df = pd.read.csv("digit-recognizer/sample_submission.csv")


train_df.head() #Has labels for every row

test_df.head()  #Doesn't have labels just pixels for every row

#submission_df.head()


train_df, val_df = train_test_split(train_df, test_size=0.1, random_state=RANDOM_SEED, shuffle=True)




class MNISTTrainDataset(Dataset):
    def __init__(self, images, labels, indicies):
        self.images = images
        self.labels = labels
        self.indicies = indicies
        self.transform = transforms.Compose([
            transforms.ToPILImage(),
            transforms.RandomRotation(15),
            transforms.ToTensor(),
            transforms.Normalize([0.5], [0.5])

        ])

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx].reshape((28,28)).astype(np.uint8)
        label = self.labels[idx]
        index = self.indicies[idx]
        image = self.transform(image)

        return {"image": image, "label": label, "index": index}



class MNISTValDataset(Dataset):
    def __init__(self, images, labels, indicies):
        self.images = images
        self.labels = labels
        self.indicies = indicies
        self.transform = transforms.Compose([
            #transforms.ToPILImage(),
            #transforms.RandomRotation(15),
            transforms.ToTensor(),
            transforms.Normalize([0.5], [0.5])

        ])

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx].reshape((28,28)).astype(np.uint8)
        label = self.labels[idx]
        index = self.indicies[idx]
        image = self.transform(image)

        return {"image": image, "label": label, "index": index}


class MNISTSubmitDataset(Dataset):
    def __init__(self, images, indicies):
        self.images = images
        #self.labels = labels
        self.indicies = indicies
        self.transform = transforms.Compose([
            #transforms.ToPILImage(),
            #transforms.RandomRotation(15),
            transforms.ToTensor(),
            transforms.Normalize([0.5], [0.5])

        ])

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx].reshape((28,28)).astype(np.uint8)
        #label = self.labels[idx]
        index = self.indicies[idx]
        image = self.transform(image)

        return {"image": image, "index": index}



#Plot data
plt.figure()
f, axarr = plt.subplots(1,3)

train_dataset = MNISTTrainDataset(train_df.iloc[:, 1:].values.astype(np.uint8), train_df.iloc[:, 0].values, train_df.index.values)
print(len(train_dataset))
print(train_dataset[0])
axarr[0].imshow(train_dataset[0]["image"].squeeze(), cmap="gray")
axarr[0].set_title("Train Image")
print("-"*30)

val_dataset = MNISTValDataset(val_df.iloc[:, 1:].values.astype(np.uint8), val_df.iloc[:, 0].values, val_df.index.values)
print(len(val_dataset))
print(val_dataset[0])
axarr[1].imshow(val_dataset[0]["image"].squeeze(), cmap="gray")
axarr[1].set_title("Val Image")
print("-"*30)


test_dataset = MNISTSubmitDataset(test_df.values.astype(np.uint8), test_df.index.values)
print(len(test_dataset))
print(test_dataset[0])
axarr[2].imshow(test_dataset[0]["image"].squeeze(), cmap="gray")
axarr[2].set_title("Test Image")
print("-"*30)


plt.show()




train_dataloader = DataLoader(dataset=train_dataset,
                             batch_size=BATCH_SIZE,
                             shuffle = True)

val_dataloader = DataLoader(dataset=val_dataset,
                             batch_size=BATCH_SIZE,
                             shuffle = True)

test_dataloader = DataLoader(dataset=test_dataset,
                             batch_size=BATCH_SIZE,
                             shuffle = False)




#Training Begins
#We use the Adam optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), betas=ADAM_BETAS, lr=LEARNING_RATE, weight_decay=ADAM_WEIGHT_DECAY)

start = timeit.default_timer()
for epoch in tqdm(range(EPOCHS), position=0, leave=True):
    model.train()
    train_labels = []
    train_preds = []
    train_running_loss = 0

    for idx, img_label in enumerate(tqdm(train_dataloader, position=0, leave=True)):
        img = img_label["image"].float().to(device)
        label = img_label["label"].type(torch.uint8).to(device)
        y_pred = model(img)
        y_pred_label = torch.argmax(y_pred, dim=1)

        train_labels.extend(label.cpu().detach()) #Store in CPU so we don't run out of memory
        train_preds.extend(y_pred_label.cpu().detach())

        #loss += criterion(y_pred, label)
        loss = criterion(y_pred, label)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_running_loss += loss.item()
    train_loss = train_running_loss / (idx * 1)

    #Validation
    model.eval()
    val_labels = []
    val_preds = []
    val_running_loss = 0
    with torch.no_grad():
        for idx, img_label in enumerate(tqdm(val_dataloader, position=0, leave=True)):
            img = img_label["image"].float().to(device)
            label = img_label["label"].type(torch.uint8).to(device)
            y_pred = model(img)
            y_pred_label = torch.argmax(y_pred, dim=1)

            val_labels.extend(label.cpu().detach())
            val_preds.extend(y_pred_label.cpu().detach())

            loss = criterion(y_pred, label)
            val_running_loss += loss.item()

    val_loss = val_running_loss / (idx * 1)

    print("-"*30)
    print(f"Train Loss EPOCH {epoch+1}: {train_loss: .4f}") #.4 means 4 decimal places
    print(f"Validation Loss EPOCH {epoch+1}: {val_loss: .4f}")
    print(f"Train Accuracy EPOCH {epoch+1}: {sum(1 for x,y in zip(train_preds, train_labels) if x == y) / len(train_labels):.4f}")
    print(f"Train Valid EPOCH {epoch+1}: {sum(1 for x,y in zip(val_preds, val_labels) if x == y) / len(val_labels):.4f}")
    print("-"*30)

stop = timeit.default_timer()
print(f"Training Time: {stop-start:.2f}s")


#torch.cuda.empty_cache()  #Hardware Offload


#Perform Inference with trained model
#Chehck Prediction
labels = []
ids = []
imgs = []
model.eval()
with torch.no_grad():
    for idx, sample in enumerate(tqdm(test_dataloader, position=0, leave=True)):
        img = sample["image"].to(device)
        ids.extend([int(i)+1 for i in sample["index"]])

        outputs = model(img)

        imgs.extend(img.detach().cpu())
        labels.extend([int(i) for i in torch.argmax(outputs, dim=1)])


#Show Predicted Results

plt.figure()
f, axarr = plt.subplots(2, 3)
counter = 0
for i in range(2):
    for j in range(3):
        axarr[i][j].imshow(imgs[counter].squeeze(), cmap="gray")
        axarr[i][j].set_title(f"Predicted {labels[counter]}")
        counter += 1



submission_df = pd.DataFrame(list(zip(ids, labels)),
               columns =["ImageId", "Label"])
submission_df.to_csv("submission.csv", index=False)
submission_df.head()



#Print Profiler Data
print(prof.key_averages().table(sort_by="cpu_memory_usage", row_limit=10))
# Out:
# cuda
# torch.Size([512, 50, 16])
# torch.Size([512, 10])
# STAGE:2024-03-04 02:24:33 34:34 ActivityProfilerController.cpp:312] Completed Stage: Warm Up
# STAGE:2024-03-04 02:24:33 34:34 ActivityProfilerController.cpp:318] Completed Stage: Collection
# STAGE:2024-03-04 02:24:33 34:34 ActivityProfilerController.cpp:322] Completed Stage: Post Processing
# /opt/conda/lib/python3.10/site-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# 37800
# {'image': tensor([[[-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000,  0.2314,  0.9922,  0.3020, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -0.9373,
#           -0.3804,  0.2314,  0.9843,  0.9843, -0.7176, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -0.0902,  0.5843,
#            0.9843,  0.9843,  0.9843,  0.9451,  0.8902, -0.5843, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -0.1137,  0.9608,
#            0.9922,  0.9843, -0.3412, -0.5059, -0.7176, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -0.6784,  0.7725,  0.9843,
#            0.9137, -0.1294, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000,  0.3412,  0.9843,  0.6392,
#           -0.7255, -1.0000, -1.0000, -1.0000,  0.3176,  0.3176, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000,  0.8353,  0.5608, -0.8588,
#           -1.0000, -1.0000, -0.9373,  0.2235,  0.6314, -0.2392, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000,  0.8902, -0.5608, -1.0000,
#           -1.0000, -1.0000, -0.5529,  0.7647,  0.8902, -0.2863, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000,  0.4275,  0.8196, -0.8824,
#           -0.8275, -0.8275,  0.9843,  0.0510, -0.7176, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000,  0.6157,  0.8667,  0.4980,
#            0.9843,  1.0000, -0.1843, -0.9059, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -0.9137,  0.6157,  0.9843,  0.9843,
#            0.9843,  0.5059, -0.1843, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -0.9451,  0.5765,  0.9922,  0.9922,
#            0.0196, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -0.6627,  0.9922,  0.9843,  0.2627,
#            0.2627, -0.9137, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -0.7176,  0.2392, -0.0745,  0.7020,
#            0.9451, -0.2784, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -0.0902,  0.9686, -1.0000, -0.8745,
#            0.8196,  0.3647, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000,  0.6627,  0.4510, -1.0000, -1.0000,
#           -0.0118,  0.9843, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000,  0.6627, -0.1608, -1.0000, -1.0000,
#           -1.0000,  0.6706,  0.3176, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -0.4902,  0.9922, -0.8588, -1.0000, -1.0000,
#           -1.0000, -1.0000,  0.0353,  0.8039, -0.7882, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -0.6627,  0.8824,  0.9686, -0.0667,
#           -0.8431, -0.8824, -0.0667,  0.6627, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000,  0.2471,  0.9686,  0.9843,
#            0.9294,  0.7725,  0.9843, -0.3725, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -0.3725,  0.7882,  0.1529,
#            0.2235,  0.9843,  0.2941, -0.3725, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -0.6627, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000]]]), 'label': 8, 'index': 22460}
# ------------------------------
# 4200
# {'image': tensor([[[-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -0.9765,
#           -0.5137,  0.4510,  1.0000,  0.7961, -0.7804, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,  0.3569,
#            0.9843,  0.9843,  0.9843,  0.9843, -0.3647, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -0.9843, -0.0118,  0.9686,
#            0.3961, -0.5686, -0.6000,  0.9843,  0.2235, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -0.4667,  0.9843,  0.2078,
#           -1.0000, -1.0000, -0.8980,  0.7020,  0.2235, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -0.9294,  0.7961,  0.4745, -0.9529,
#           -1.0000, -1.0000, -0.8275,  0.9843,  0.2235, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -0.9137,  0.9843,  0.3098, -1.0000,
#           -1.0000, -1.0000, -0.8275,  0.9843,  0.2549, -0.9137, -0.9294,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -0.9294,  0.8431,  0.3098, -1.0000,
#           -1.0000, -1.0000, -0.8275,  0.9843,  0.9843,  0.9843,  0.4745,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000,  0.2314,  0.8275, -0.8745,
#           -1.0000, -1.0000, -0.5373,  0.9843,  0.9843,  0.9137, -0.3882,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -0.1765,  0.9843, -0.8353,
#           -1.0000, -0.9529,  0.4431,  0.9843,  0.9373, -0.4196, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -0.6157,  0.9843, -0.1059,
#           -1.0000, -0.0902,  0.9843,  0.9843, -0.3176, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -0.9137,  0.3176,  0.9608,
#            0.5686,  0.8980,  0.9294,  0.0667, -0.9216, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -0.3176,  0.9843,
#            0.9843,  0.9843,  0.7412, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -0.7412,  0.5451,  0.9843,
#            0.9843,  0.9843, -0.2235, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -0.6392,  0.3647,  0.9843,  0.9843,
#            0.9843,  0.4039, -0.9765, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -0.6549,  0.8588,  0.9843,  0.8275,  0.0039,
#            0.6078,  0.2627, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000,  0.2157,  0.9843,  0.7255, -0.8510, -1.0000,
#            0.2706,  0.4510, -0.9686, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000,  0.4824,  0.9843,  0.7569, -0.4667, -1.0000,
#           -0.4275,  0.9843, -0.5294, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000,  0.2941,  0.8510,  0.9843,  0.9765,  0.8980,
#            0.6549,  0.9843, -0.0275, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -0.7176,  0.1137,  0.6235,  0.9843,
#            0.9843,  0.9843, -0.0275, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -0.8980,  0.0667,
#            0.6784,  0.3176, -0.8039, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000]]]), 'label': 8, 'index': 5457}
# ------------------------------
# 28000
# {'image': tensor([[[-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -0.9216, -0.8667, -0.8667, -0.8667,
#           -0.8667, -0.3647,  0.4118,  0.4118, -0.7255, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000,  0.0902,  0.9843,  0.9843,  0.9843,
#            0.9843,  0.9843,  0.9843,  0.9843, -0.6235, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -0.5294,  0.7882,  0.9843,  0.9843,  0.9843,
#            0.9843,  0.9843,  0.9843,  0.9843,  0.6235,  0.5451, -0.6392,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000,  0.6706,  0.9843,  0.9843,  0.9843,  0.9843,
#            0.9843,  0.9843,  0.9843,  0.9843,  0.9843,  0.9843,  0.7490,
#           -0.5922, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -0.4824,  0.8118,  0.9843,  0.9843,  0.9843,
#           -0.1529, -0.6863, -0.6863, -0.0980,  0.9137,  0.9843,  0.9843,
#            0.0510, -0.9765, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -0.5059, -0.1059, -0.1059, -0.1059,
#           -0.7098, -1.0000, -1.0000, -1.0000,  0.6078,  0.9843,  0.9843,
#            0.9843, -0.8824, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -0.5529,  0.9843,  0.9843,
#            0.9843, -0.8824, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -0.6706,  0.9843,  0.9843,
#            0.9843, -0.8824, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -0.2549,  0.9843,  0.9843,
#            0.9843, -0.8824, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000,  0.6078,  0.9843,  0.9843,
#            0.9843, -0.8824, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -0.5216, -0.2235,
#           -0.2471, -1.0000, -1.0000, -0.6471,  0.7569,  0.9843,  0.9843,
#            0.5294, -0.9216, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -0.9137,
#           -0.8039, -0.1765, -0.3490,  0.4824,  0.4824,  0.7882,  0.9843,
#            0.9686,  0.4824,  0.4824,  0.7098,  0.9843,  0.9843,  0.6471,
#           -0.7882, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -0.6706, -0.0902,  0.3569,
#            0.9843,  0.9843,  0.9843,  0.9843,  0.9843,  0.9843,  0.9843,
#            0.9843,  0.9843,  0.9843,  0.9843,  0.9843,  0.9843,  0.7333,
#           -0.0902, -0.9451, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -0.0745,  0.9843,  0.9843,
#            0.9843,  0.9843,  0.9216,  0.6627,  0.7412,  0.9843,  0.9843,
#            0.9843,  0.9843,  0.9843,  0.9843,  0.9843,  0.9843,  0.9843,
#            0.9843,  0.2549, -0.8824, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000,  0.9922,  0.9843,  0.9843,
#            0.9843,  0.4824, -0.2235, -1.0000, -0.7490,  0.5843,  0.9843,
#            0.9843,  0.9843,  0.8824, -0.0431, -0.0431,  0.4902,  0.9843,
#            0.9843,  0.9843,  0.3647, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000,  1.0000,  0.9843,  0.9843,
#            0.9843,  0.8667,  0.7412,  0.7412,  0.7412,  0.8902,  0.9843,
#            0.9843,  0.8039, -0.4510, -1.0000, -1.0000, -0.8667,  0.3725,
#            0.7961,  0.9843,  0.9843, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000,  0.2392,  0.9843,  0.9843,
#            0.9843,  0.9843,  0.9843,  0.9843,  0.9843,  0.9843,  0.6078,
#           -0.1686, -0.4902, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -0.5137,  0.9137,  0.2314, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -0.9529, -0.7961,  0.4039,
#            0.4039,  0.4039,  0.4039,  0.4039, -0.7647, -0.8824, -0.9216,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -0.8902, -0.9529, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000],
#          [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#           -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000]]]), 'index': 0}
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.27it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11.53it/s]
# ------------------------------
# Train Loss EPOCH 1:  2.2155
# Validation Loss EPOCH 1:  2.2252
#   1%|▏         | 1/70 [00:18<21:06, 18.35s/it]
# Train Accuracy EPOCH 1: 0.1875
# Train Valid EPOCH 1: 0.2833
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.35it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.20it/s]
# ------------------------------
# Train Loss EPOCH 2:  1.9061
# Validation Loss EPOCH 2:  1.9401
#   3%|▎         | 2/70 [00:36<20:35, 18.17s/it]
# Train Accuracy EPOCH 2: 0.3251
# Train Valid EPOCH 2: 0.3950
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.30it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.09it/s]
# ------------------------------
# Train Loss EPOCH 3:  1.7668
# Validation Loss EPOCH 3:  1.8144
#   4%|▍         | 3/70 [00:54<20:20, 18.21s/it]
# Train Accuracy EPOCH 3: 0.3883
# Train Valid EPOCH 3: 0.4398
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.31it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.28it/s]
# ------------------------------
# Train Loss EPOCH 4:  1.6810
# Validation Loss EPOCH 4:  1.9024
#   6%|▌         | 4/70 [01:12<20:02, 18.22s/it]
# Train Accuracy EPOCH 4: 0.4216
# Train Valid EPOCH 4: 0.3983
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.33it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11.62it/s]
# ------------------------------
# Train Loss EPOCH 5:  1.6312
# Validation Loss EPOCH 5:  1.6502
#   7%|▋         | 5/70 [01:31<19:43, 18.21s/it]
# Train Accuracy EPOCH 5: 0.4408
# Train Valid EPOCH 5: 0.4960
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.33it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.30it/s]
# ------------------------------
# Train Loss EPOCH 6:  1.5694
# Validation Loss EPOCH 6:  1.6173
#   9%|▊         | 6/70 [01:49<19:24, 18.19s/it]
# Train Accuracy EPOCH 6: 0.4669
# Train Valid EPOCH 6: 0.5183
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.41it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.00it/s]
# ------------------------------
# Train Loss EPOCH 7:  1.5296
# Validation Loss EPOCH 7:  1.5488
#  10%|█         | 7/70 [02:07<18:59, 18.09s/it]
# Train Accuracy EPOCH 7: 0.4830
# Train Valid EPOCH 7: 0.5571
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.51it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11.97it/s]
# ------------------------------
# Train Loss EPOCH 8:  1.4911
# Validation Loss EPOCH 8:  1.5405
#  11%|█▏        | 8/70 [02:24<18:29, 17.90s/it]
# Train Accuracy EPOCH 8: 0.4962
# Train Valid EPOCH 8: 0.5355
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.35it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.32it/s]
# ------------------------------
# Train Loss EPOCH 9:  1.4584
# Validation Loss EPOCH 9:  1.4528
#  13%|█▎        | 9/70 [02:42<18:14, 17.95s/it]
# Train Accuracy EPOCH 9: 0.5070
# Train Valid EPOCH 9: 0.5660
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.41it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11.66it/s]
# ------------------------------
# Train Loss EPOCH 10:  1.4127
# Validation Loss EPOCH 10:  1.4571
#  14%|█▍        | 10/70 [03:00<17:55, 17.93s/it]
# Train Accuracy EPOCH 10: 0.5257
# Train Valid EPOCH 10: 0.5452
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.32it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11.92it/s]
# ------------------------------
# Train Loss EPOCH 11:  1.3899
# Validation Loss EPOCH 11:  1.4197
#  16%|█▌        | 11/70 [03:18<17:43, 18.02s/it]
# Train Accuracy EPOCH 11: 0.5321
# Train Valid EPOCH 11: 0.5702
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.27it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.10it/s]
# ------------------------------
# Train Loss EPOCH 12:  1.3623
# Validation Loss EPOCH 12:  1.3289
#  17%|█▋        | 12/70 [03:37<17:31, 18.13s/it]
# Train Accuracy EPOCH 12: 0.5415
# Train Valid EPOCH 12: 0.6005
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.21it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11.49it/s]
# ------------------------------
# Train Loss EPOCH 13:  1.3373
# Validation Loss EPOCH 13:  1.3660
#  19%|█▊        | 13/70 [03:55<17:23, 18.30s/it]
# Train Accuracy EPOCH 13: 0.5506
# Train Valid EPOCH 13: 0.5919
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.28it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11.44it/s]
# ------------------------------
# Train Loss EPOCH 14:  1.3067
# Validation Loss EPOCH 14:  1.3155
#  20%|██        | 14/70 [04:14<17:06, 18.33s/it]
# Train Accuracy EPOCH 14: 0.5613
# Train Valid EPOCH 14: 0.6131
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.32it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11.64it/s]
# ------------------------------
# Train Loss EPOCH 15:  1.2914
# Validation Loss EPOCH 15:  1.2773
#  21%|██▏       | 15/70 [04:32<16:46, 18.31s/it]
# Train Accuracy EPOCH 15: 0.5643
# Train Valid EPOCH 15: 0.6243
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.38it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11.18it/s]
# ------------------------------
# Train Loss EPOCH 16:  1.2587
# Validation Loss EPOCH 16:  1.2654
#  23%|██▎       | 16/70 [04:50<16:24, 18.22s/it]
# Train Accuracy EPOCH 16: 0.5797
# Train Valid EPOCH 16: 0.6164
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.25it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11.72it/s]
# ------------------------------
# Train Loss EPOCH 17:  1.2288
# Validation Loss EPOCH 17:  1.1981
#  24%|██▍       | 17/70 [05:09<16:10, 18.30s/it]
# Train Accuracy EPOCH 17: 0.5914
# Train Valid EPOCH 17: 0.6533
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.24it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.25it/s]
# ------------------------------
# Train Loss EPOCH 18:  1.2109
# Validation Loss EPOCH 18:  1.1271
#  26%|██▌       | 18/70 [05:27<15:55, 18.37s/it]
# Train Accuracy EPOCH 18: 0.5955
# Train Valid EPOCH 18: 0.6781
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.32it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.32it/s]
# ------------------------------
# Train Loss EPOCH 19:  1.1889
# Validation Loss EPOCH 19:  1.1031
#  27%|██▋       | 19/70 [05:45<15:33, 18.31s/it]
# Train Accuracy EPOCH 19: 0.6044
# Train Valid EPOCH 19: 0.6855
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.23it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.03it/s]
# ------------------------------
# Train Loss EPOCH 20:  1.1794
# Validation Loss EPOCH 20:  1.1103
#  29%|██▊       | 20/70 [06:04<15:19, 18.39s/it]
# Train Accuracy EPOCH 20: 0.6043
# Train Valid EPOCH 20: 0.6838
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.35it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.27it/s]
# ------------------------------
# Train Loss EPOCH 21:  1.1518
# Validation Loss EPOCH 21:  1.1053
#  30%|███       | 21/70 [06:22<14:56, 18.30s/it]
# Train Accuracy EPOCH 21: 0.6139
# Train Valid EPOCH 21: 0.6826
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.38it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11.53it/s]
# ------------------------------
# Train Loss EPOCH 22:  1.1495
# Validation Loss EPOCH 22:  1.0471
#  31%|███▏      | 22/70 [06:40<14:34, 18.21s/it]
# Train Accuracy EPOCH 22: 0.6185
# Train Valid EPOCH 22: 0.7002
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.28it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.17it/s]
# ------------------------------
# Train Loss EPOCH 23:  1.1224
# Validation Loss EPOCH 23:  1.0750
#  33%|███▎      | 23/70 [06:58<14:17, 18.25s/it]
# Train Accuracy EPOCH 23: 0.6283
# Train Valid EPOCH 23: 0.6729
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.42it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.57it/s]
# ------------------------------
# Train Loss EPOCH 24:  1.1100
# Validation Loss EPOCH 24:  1.0563
#  34%|███▍      | 24/70 [07:16<13:52, 18.11s/it]
# Train Accuracy EPOCH 24: 0.6291
# Train Valid EPOCH 24: 0.6752
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.47it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.57it/s]
# ------------------------------
# Train Loss EPOCH 25:  1.0896
# Validation Loss EPOCH 25:  1.0029
#  36%|███▌      | 25/70 [07:34<13:27, 17.95s/it]
# Train Accuracy EPOCH 25: 0.6375
# Train Valid EPOCH 25: 0.7148
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.49it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11.52it/s]
# ------------------------------
# Train Loss EPOCH 26:  1.0764
# Validation Loss EPOCH 26:  0.9985
#  37%|███▋      | 26/70 [07:51<13:05, 17.85s/it]
# Train Accuracy EPOCH 26: 0.6396
# Train Valid EPOCH 26: 0.7174
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.44it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.32it/s]
# ------------------------------
# Train Loss EPOCH 27:  1.0562
# Validation Loss EPOCH 27:  0.9649
#  39%|███▊      | 27/70 [08:09<12:45, 17.81s/it]
# Train Accuracy EPOCH 27: 0.6481
# Train Valid EPOCH 27: 0.7190
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.46it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.51it/s]
# ------------------------------
# Train Loss EPOCH 28:  1.0469
# Validation Loss EPOCH 28:  0.9389
#  40%|████      | 28/70 [08:27<12:25, 17.76s/it]
# Train Accuracy EPOCH 28: 0.6470
# Train Valid EPOCH 28: 0.7267
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.48it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.27it/s]
# ------------------------------
# Train Loss EPOCH 29:  1.0326
# Validation Loss EPOCH 29:  0.9667
#  41%|████▏     | 29/70 [08:44<12:05, 17.70s/it]
# Train Accuracy EPOCH 29: 0.6538
# Train Valid EPOCH 29: 0.7150
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.47it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.46it/s]
# ------------------------------
# Train Loss EPOCH 30:  1.0171
# Validation Loss EPOCH 30:  0.9036
#  43%|████▎     | 30/70 [09:02<11:46, 17.67s/it]
# Train Accuracy EPOCH 30: 0.6586
# Train Valid EPOCH 30: 0.7367
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.44it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11.78it/s]
# ------------------------------
# Train Loss EPOCH 31:  1.0227
# Validation Loss EPOCH 31:  0.9055
#  44%|████▍     | 31/70 [09:20<11:30, 17.70s/it]
# Train Accuracy EPOCH 31: 0.6596
# Train Valid EPOCH 31: 0.7376
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.41it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.09it/s]
# ------------------------------
# Train Loss EPOCH 32:  0.9990
# Validation Loss EPOCH 32:  0.8829
#  46%|████▌     | 32/70 [09:37<11:14, 17.74s/it]
# Train Accuracy EPOCH 32: 0.6672
# Train Valid EPOCH 32: 0.7445
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.45it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11.88it/s]
# ------------------------------
# Train Loss EPOCH 33:  0.9856
# Validation Loss EPOCH 33:  0.8838
#  47%|████▋     | 33/70 [09:55<10:56, 17.73s/it]
# Train Accuracy EPOCH 33: 0.6674
# Train Valid EPOCH 33: 0.7467
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.28it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11.43it/s]
# ------------------------------
# Train Loss EPOCH 34:  0.9774
# Validation Loss EPOCH 34:  0.8919
#  49%|████▊     | 34/70 [10:13<10:45, 17.93s/it]
# Train Accuracy EPOCH 34: 0.6740
# Train Valid EPOCH 34: 0.7421
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.28it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.06it/s]
# ------------------------------
# Train Loss EPOCH 35:  0.9639
# Validation Loss EPOCH 35:  0.8631
#  50%|█████     | 35/70 [10:32<10:31, 18.06s/it]
# Train Accuracy EPOCH 35: 0.6769
# Train Valid EPOCH 35: 0.7502
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.23it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11.65it/s]
# ------------------------------
# Train Loss EPOCH 36:  0.9552
# Validation Loss EPOCH 36:  0.8623
#  51%|█████▏    | 36/70 [10:50<10:19, 18.22s/it]
# Train Accuracy EPOCH 36: 0.6812
# Train Valid EPOCH 36: 0.7476
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.25it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11.80it/s]
# ------------------------------
# Train Loss EPOCH 37:  0.9448
# Validation Loss EPOCH 37:  0.9052
#  53%|█████▎    | 37/70 [11:09<10:04, 18.31s/it]
# Train Accuracy EPOCH 37: 0.6837
# Train Valid EPOCH 37: 0.7221
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.30it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11.93it/s]
# ------------------------------
# Train Loss EPOCH 38:  0.9437
# Validation Loss EPOCH 38:  0.8264
#  54%|█████▍    | 38/70 [11:27<09:45, 18.30s/it]
# Train Accuracy EPOCH 38: 0.6838
# Train Valid EPOCH 38: 0.7674
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.28it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11.59it/s]
# ------------------------------
# Train Loss EPOCH 39:  0.9366
# Validation Loss EPOCH 39:  0.8116
#  56%|█████▌    | 39/70 [11:46<09:28, 18.34s/it]
# Train Accuracy EPOCH 39: 0.6855
# Train Valid EPOCH 39: 0.7512
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.30it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11.71it/s]
# ------------------------------
# Train Loss EPOCH 40:  0.9168
# Validation Loss EPOCH 40:  0.8462
#  57%|█████▋    | 40/70 [12:04<09:09, 18.33s/it]
# Train Accuracy EPOCH 40: 0.6937
# Train Valid EPOCH 40: 0.7395
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.33it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.25it/s]
# ------------------------------
# Train Loss EPOCH 41:  0.9111
# Validation Loss EPOCH 41:  0.7930
#  59%|█████▊    | 41/70 [12:22<08:50, 18.28s/it]
# Train Accuracy EPOCH 41: 0.6945
# Train Valid EPOCH 41: 0.7662
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.41it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.03it/s]
# ------------------------------
# Train Loss EPOCH 42:  0.9065
# Validation Loss EPOCH 42:  0.7779
#  60%|██████    | 42/70 [12:40<08:28, 18.14s/it]
# Train Accuracy EPOCH 42: 0.6951
# Train Valid EPOCH 42: 0.7831
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.36it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.00it/s]
# ------------------------------
# Train Loss EPOCH 43:  0.9110
# Validation Loss EPOCH 43:  0.8102
#  61%|██████▏   | 43/70 [12:58<08:09, 18.12s/it]
# Train Accuracy EPOCH 43: 0.6943
# Train Valid EPOCH 43: 0.7621
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.32it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11.94it/s]
# ------------------------------
# Train Loss EPOCH 44:  0.8809
# Validation Loss EPOCH 44:  0.8070
#  63%|██████▎   | 44/70 [13:16<07:51, 18.14s/it]
# Train Accuracy EPOCH 44: 0.7077
# Train Valid EPOCH 44: 0.7595
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.37it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.16it/s]
# ------------------------------
# Train Loss EPOCH 45:  0.8858
# Validation Loss EPOCH 45:  0.7808
#  64%|██████▍   | 45/70 [13:34<07:32, 18.10s/it]
# Train Accuracy EPOCH 45: 0.7030
# Train Valid EPOCH 45: 0.7748
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.48it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.52it/s]
# ------------------------------
# Train Loss EPOCH 46:  0.8825
# Validation Loss EPOCH 46:  0.8042
#  66%|██████▌   | 46/70 [13:52<07:10, 17.93s/it]
# Train Accuracy EPOCH 46: 0.7019
# Train Valid EPOCH 46: 0.7650
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.42it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11.58it/s]
# ------------------------------
# Train Loss EPOCH 47:  0.8647
# Validation Loss EPOCH 47:  0.7450
#  67%|██████▋   | 47/70 [14:10<06:51, 17.91s/it]
# Train Accuracy EPOCH 47: 0.7098
# Train Valid EPOCH 47: 0.7824
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.45it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.46it/s]
# ------------------------------
# Train Loss EPOCH 48:  0.8733
# Validation Loss EPOCH 48:  0.7961
#  69%|██████▊   | 48/70 [14:27<06:32, 17.84s/it]
# Train Accuracy EPOCH 48: 0.7071
# Train Valid EPOCH 48: 0.7693
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.42it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.34it/s]
# ------------------------------
# Train Loss EPOCH 49:  0.8579
# Validation Loss EPOCH 49:  0.7491
#  70%|███████   | 49/70 [14:45<06:14, 17.82s/it]
# Train Accuracy EPOCH 49: 0.7131
# Train Valid EPOCH 49: 0.7793
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.43it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.37it/s]
# ------------------------------
# Train Loss EPOCH 50:  0.8692
# Validation Loss EPOCH 50:  0.7303
#  71%|███████▏  | 50/70 [15:03<05:55, 17.80s/it]
# Train Accuracy EPOCH 50: 0.7078
# Train Valid EPOCH 50: 0.7869
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.45it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.19it/s]
# ------------------------------
# Train Loss EPOCH 51:  0.8554
# Validation Loss EPOCH 51:  0.7182
#  73%|███████▎  | 51/70 [15:20<05:37, 17.77s/it]
# Train Accuracy EPOCH 51: 0.7127
# Train Valid EPOCH 51: 0.7900
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.51it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.44it/s]
# ------------------------------
# Train Loss EPOCH 52:  0.8432
# Validation Loss EPOCH 52:  0.7521
#  74%|███████▍  | 52/70 [15:38<05:18, 17.68s/it]
# Train Accuracy EPOCH 52: 0.7186
# Train Valid EPOCH 52: 0.7862
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.36it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.21it/s]
# ------------------------------
# Train Loss EPOCH 53:  0.8537
# Validation Loss EPOCH 53:  0.7171
#  76%|███████▌  | 53/70 [15:56<05:02, 17.79s/it]
# Train Accuracy EPOCH 53: 0.7120
# Train Valid EPOCH 53: 0.7940
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.40it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.21it/s]
# ------------------------------
# Train Loss EPOCH 54:  0.8349
# Validation Loss EPOCH 54:  0.7464
#  77%|███████▋  | 54/70 [16:14<04:45, 17.84s/it]
# Train Accuracy EPOCH 54: 0.7162
# Train Valid EPOCH 54: 0.7802
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.41it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.26it/s]
# ------------------------------
# Train Loss EPOCH 55:  0.8287
# Validation Loss EPOCH 55:  0.7644
#  79%|███████▊  | 55/70 [16:32<04:27, 17.84s/it]
# Train Accuracy EPOCH 55: 0.7219
# Train Valid EPOCH 55: 0.7717
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.51it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.29it/s]
# ------------------------------
# Train Loss EPOCH 56:  0.8273
# Validation Loss EPOCH 56:  0.7319
#  80%|████████  | 56/70 [16:49<04:08, 17.73s/it]
# Train Accuracy EPOCH 56: 0.7219
# Train Valid EPOCH 56: 0.7783
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.46it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.49it/s]
# ------------------------------
# Train Loss EPOCH 57:  0.8221
# Validation Loss EPOCH 57:  0.7293
#  81%|████████▏ | 57/70 [17:07<03:50, 17.70s/it]
# Train Accuracy EPOCH 57: 0.7255
# Train Valid EPOCH 57: 0.7871
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.45it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.48it/s]
# ------------------------------
# Train Loss EPOCH 58:  0.8153
# Validation Loss EPOCH 58:  0.7113
#  83%|████████▎ | 58/70 [17:25<03:32, 17.70s/it]
# Train Accuracy EPOCH 58: 0.7284
# Train Valid EPOCH 58: 0.7940
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.49it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.53it/s]
# ------------------------------
# Train Loss EPOCH 59:  0.8142
# Validation Loss EPOCH 59:  0.6961
#  84%|████████▍ | 59/70 [17:42<03:14, 17.65s/it]
# Train Accuracy EPOCH 59: 0.7261
# Train Valid EPOCH 59: 0.8026
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.49it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11.92it/s]
# ------------------------------
# Train Loss EPOCH 60:  0.8109
# Validation Loss EPOCH 60:  0.7201
#  86%|████████▌ | 60/70 [18:00<02:56, 17.62s/it]
# Train Accuracy EPOCH 60: 0.7279
# Train Valid EPOCH 60: 0.7929
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.47it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.35it/s]
# ------------------------------
# Train Loss EPOCH 61:  0.8113
# Validation Loss EPOCH 61:  0.7009
#  87%|████████▋ | 61/70 [18:17<02:38, 17.62s/it]
# Train Accuracy EPOCH 61: 0.7272
# Train Valid EPOCH 61: 0.7962
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.44it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.16it/s]
# ------------------------------
# Train Loss EPOCH 62:  0.8000
# Validation Loss EPOCH 62:  0.6837
#  89%|████████▊ | 62/70 [18:35<02:21, 17.66s/it]
# Train Accuracy EPOCH 62: 0.7326
# Train Valid EPOCH 62: 0.8055
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.46it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.18it/s]
# ------------------------------
# Train Loss EPOCH 63:  0.8014
# Validation Loss EPOCH 63:  0.6761
#  90%|█████████ | 63/70 [18:53<02:03, 17.66s/it]
# Train Accuracy EPOCH 63: 0.7312
# Train Valid EPOCH 63: 0.8000
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.37it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.07it/s]
# ------------------------------
# Train Loss EPOCH 64:  0.7956
# Validation Loss EPOCH 64:  0.6933
#  91%|█████████▏| 64/70 [19:11<01:46, 17.77s/it]
# Train Accuracy EPOCH 64: 0.7330
# Train Valid EPOCH 64: 0.7929
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.37it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.15it/s]
# ------------------------------
# Train Loss EPOCH 65:  0.7939
# Validation Loss EPOCH 65:  0.6641
#  93%|█████████▎| 65/70 [19:29<01:29, 17.84s/it]
# Train Accuracy EPOCH 65: 0.7334
# Train Valid EPOCH 65: 0.8019
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.38it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.14it/s]
# ------------------------------
# Train Loss EPOCH 66:  0.7889
# Validation Loss EPOCH 66:  0.6875
#  94%|█████████▍| 66/70 [19:47<01:11, 17.88s/it]
# Train Accuracy EPOCH 66: 0.7352
# Train Valid EPOCH 66: 0.7983
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.34it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.02it/s]
# ------------------------------
# Train Loss EPOCH 67:  0.7871
# Validation Loss EPOCH 67:  0.6729
#  96%|█████████▌| 67/70 [20:05<00:53, 17.96s/it]
# Train Accuracy EPOCH 67: 0.7345
# Train Valid EPOCH 67: 0.8062
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.35it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.03it/s]
# ------------------------------
# Train Loss EPOCH 68:  0.7795
# Validation Loss EPOCH 68:  0.7418
#  97%|█████████▋| 68/70 [20:23<00:36, 18.00s/it]
# Train Accuracy EPOCH 68: 0.7381
# Train Valid EPOCH 68: 0.7864
# ------------------------------
# 100%|██████████| 74/74 [00:17<00:00,  4.33it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.20it/s]
# ------------------------------
# Train Loss EPOCH 69:  0.7828
# Validation Loss EPOCH 69:  0.6682
#  99%|█████████▊| 69/70 [20:41<00:18, 18.05s/it]
# Train Accuracy EPOCH 69: 0.7357
# Train Valid EPOCH 69: 0.8048
# ------------------------------
# 100%|██████████| 74/74 [00:16<00:00,  4.39it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.19it/s]
# ------------------------------
# Train Loss EPOCH 70:  0.7811
# Validation Loss EPOCH 70:  0.6702
# 100%|██████████| 70/70 [20:59<00:00, 17.99s/it]
# Train Accuracy EPOCH 70: 0.7388
# Train Valid EPOCH 70: 0.8079
# ------------------------------
# Training Time: 1259.57s
# 100%|██████████| 55/55 [00:05<00:00, 10.40it/s]
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg       CPU Mem  Self CPU Mem      CUDA Mem  Self CUDA Mem    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        34.51%       4.010ms        99.90%      11.609ms      11.609ms       0.000us         0.00%      78.000us      78.000us           0 b           0 b           0 b      -5.05 Mb             1
#                                            aten::expand         7.09%     824.000us         7.13%     829.000us     829.000us       0.000us         0.00%       0.000us       0.000us           0 b           0 b           0 b           0 b             1
#                                        aten::as_strided         0.06%       7.000us         0.06%       7.000us       3.500us       0.000us         0.00%       0.000us       0.000us           0 b           0 b           0 b           0 b             2
#                                            aten::conv2d         0.08%       9.000us        40.10%       4.660ms       4.660ms       0.000us         0.00%      48.000us      48.000us           0 b           0 b       1.53 Mb           0 b             1
#                                       aten::convolution         0.20%      23.000us        40.02%       4.651ms       4.651ms       0.000us         0.00%      48.000us      48.000us           0 b           0 b       1.53 Mb           0 b             1
#                                      aten::_convolution        14.35%       1.668ms        39.82%       4.628ms       4.628ms       0.000us         0.00%      48.000us      48.000us           0 b           0 b       1.53 Mb           0 b             1
#                                 aten::cudnn_convolution        24.56%       2.854ms        24.87%       2.890ms       2.890ms      37.000us        47.44%      37.000us      37.000us           0 b           0 b       1.53 Mb       1.53 Mb             1
#                                   cudaStreamIsCapturing         0.03%       3.000us         0.03%       3.000us       1.500us       0.000us         0.00%       0.000us       0.000us           0 b           0 b           0 b           0 b             2
#                                   cudaStreamGetPriority         0.01%       1.000us         0.01%       1.000us       1.000us       0.000us         0.00%       0.000us       0.000us           0 b           0 b           0 b           0 b             1
#                        cudaDeviceGetStreamPriorityRange         0.00%       0.000us         0.00%       0.000us       0.000us       0.000us         0.00%       0.000us       0.000us           0 b           0 b           0 b           0 b             1
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 11.621ms
# Self CUDA time total: 78.000us
